# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
tf.random.set_seed(100)

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("vgsales.csv")
print(df.shape)
df.describe(include='all')

df = df.dropna()
df = df.drop(columns=['Rank', 'Name', 'NA_Sales', 'JP_Sales', 'Other_Sales'], axis=1)
df = pd.get_dummies(df, columns=['Platform'], drop_first=True, prefix='Platform')
df = pd.get_dummies(df, columns=['Genre'], drop_first=True, prefix='Genra')
df = pd.get_dummies(df, columns=['Publisher'], drop_first=True, prefix='Publisher')
df.head()
# Out:
# (16598, 11)
#      Year  EU_Sales  Global_Sales  Platform_3DO  Platform_3DS  Platform_DC  \
# 0  2006.0     29.02         82.74         False         False        False
# 1  1985.0      3.58         40.24         False         False        False
# 2  2008.0     12.88         35.82         False         False        False
# 3  2009.0     11.01         33.00         False         False        False
# 4  1996.0      8.89         31.37         False         False        False
#
#    Platform_DS  Platform_GB  Platform_GBA  Platform_GC  ...  \
# 0        False        False         False        False  ...
# 1        False        False         False        False  ...
# 2        False        False         False        False  ...
# 3        False        False         False        False  ...
# 4        False         True         False        False  ...
#
#    Publisher_Zushi Games  Publisher_bitComposer Games  \
# 0                  False                        False
# 1                  False                        False
# 2                  False                        False
# 3                  False                        False
# 4                  False                        False
#
#    Publisher_dramatic create  Publisher_fonfun  Publisher_iWin  \
# 0                      False             False           False
# 1                      False             False           False
# 2                      False             False           False
# 3                      False             False           False
# 4                      False             False           False
#
#    Publisher_id Software  Publisher_imageepoch Inc.  \
# 0                  False                      False
# 1                  False                      False
# 2                  False                      False
# 3                  False                      False
# 4                  False                      False
#
#    Publisher_inXile Entertainment  Publisher_mixi, Inc  Publisher_responDESIGN
# 0                           False                False                   False
# 1                           False                False                   False
# 2                           False                False                   False
# 3                           False                False                   False
# 4                           False                False                   False
#
# [5 rows x 619 columns]

# %%
target_variable = ['EU_Sales']
predictors = list(set(list(df.columns))-set(target_variable))
X = df[predictors].values
X = X.astype(float)
y = df[target_variable].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=100)

print(X_train.shape); print(X_test.shape)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(32, input_shape = (X_train.shape[1],), activation = 'relu'))
model.add(tf.keras.layers.Dense(16, activation= "relu"))
model.add(tf.keras.layers.Dense(8, activation= "relu"))
model.add(tf.keras.layers.Dense(4, activation= "relu"))
model.add(tf.keras.layers.Dense(1))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss = 'mae', metrics = ['mae'], optimizer = optimizer)

model.fit(X_train, y_train, epochs=50)

print(model.evaluate(X_train, y_train))

print(model.evaluate(X_test, y_test))
# Out:
# (11403, 618)
# (4888, 618)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2.8472 - mae: 2.8472
# Epoch 2/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 3/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 4/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 5/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 6/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 7/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 8/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 9/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 10/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 11/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 12/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1364 - mae: 0.1364
# Epoch 13/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 14/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 15/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 16/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1368 - mae: 0.1368
# Epoch 17/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 18/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 19/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 20/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 21/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 22/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 23/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1367 - mae: 0.1367
# Epoch 24/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 25/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 26/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 27/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 28/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 29/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 30/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 31/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 32/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 33/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 34/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1364 - mae: 0.1364
# Epoch 35/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1367 - mae: 0.1367
# Epoch 36/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 37/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 38/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1368 - mae: 0.1368
# Epoch 39/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 40/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 41/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 42/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 43/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 44/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 45/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 46/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - mae: 0.1365
# Epoch 47/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 48/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 49/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1366 - mae: 0.1366
# Epoch 50/50
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1365 - mae: 0.1365
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1450 - mae: 0.1450
# [0.14126558601856232, 0.14126558601856232]
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1574 - mae: 0.1574
# [0.14861063659191132, 0.14861063659191132]

# %%
print(model.evaluate(X_train, y_train))
# Out:
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1450 - mae: 0.1450
# [0.14126558601856232, 0.14126558601856232]

# %%
print(model.evaluate(X_test, y_test))
# Out:
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1574 - mae: 0.1574
# [0.14861063659191132, 0.14861063659191132]

# %%
pred_train = model.predict(X_train)
r2_score(y_train, pred_train)
# Out:
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# -0.05104370877514719

# %%
pred_test = model.predict(X_test)
r2_score(y_test, pred_test)
# Out:
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# -0.07801087605862
